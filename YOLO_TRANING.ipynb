# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15833, done.
# remote: Total 15833 (delta 0), reused 0 (delta 0), pack-reused 15833
# Receiving objects: 100% (15833/15833), 14.39 MiB | 11.89 MiB/s, done.
# Resolving deltas: 100% (10666/10666), done.

# %%
# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/darknet

# %%
#verify cuda
! /usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:945:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   945 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1443:14: warning: unused variable ‘buff’ [-Wunused-variable]
#  1443 |         char buff[100];
# ...

# %%
# !cp /content/drive/MyDrive/DL_folder/obj.zip ../

# %%
# !unzip ../obj.zip -d data/
# Out:
# Archive:  ../obj.zip
#    creating: data/obj/
#   inflating: data/obj/download.jpeg
#   inflating: data/obj/download (1).jpeg
#   inflating: data/obj/download (2).jpeg
#   inflating: data/obj/download (3).jpeg
#   inflating: data/obj/a7sp8ji_high-security-number-plates_625x300_12_October_18.webp
#   inflating: data/obj/download (4).jpeg
#   inflating: data/obj/chrome-car-number-plate-500x500.webp
#   inflating: data/obj/download (5).jpeg
#   inflating: data/obj/images.jpeg
#   inflating: data/obj/images (1).jpeg
#   inflating: data/obj/images (2).jpeg
#   inflating: data/obj/Blog_Generic_Bharat-Series-Number-Plate-800x500.jpg
#   inflating: data/obj/images (3).jpeg
#   inflating: data/obj/q2.png
#   inflating: data/obj/q1qr.png
#   inflating: data/obj/q1ans.png
#   inflating: data/obj/q2ans.png
#   inflating: data/obj/Screenshot from 2023-08-20 20-43-27.png
#   inflating: data/obj/a7sp8ji_high-security-number-plates_625x300_12_October_18.txt
#   inflating: data/obj/classes.txt
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp /content/drive/MyDrive/DL_folder/obj.data ./data

# %%
# !cp /content/drive/MyDrive/DL_folder/obj.names ./data

# %%
# !cp /content/drive/MyDrive/DL_folder/yolov3_custom.cfg ./data

# %%
# !cp /content/drive/MyDrive/DL_folder/generate_train.py ./

# %%
# !pwd
# Out:
# /content/darknet

# %%
# !python generate_train.py

# %%
ls data/
# Out:
# 9k.tree     eagle.jpg    imagenet.labels.list      obj.data          scream.jpg
# coco9k.map  giraffe.jpg  imagenet.shortnames.list  obj.names         train.txt
# coco.names  goal.txt     labels/                   openimages.names  voc.names
# dog.jpg     horses.jpg   obj/                      person.jpg        yolov3_custom.cfg

# %%
# !wget http://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2024-04-11 03:08:42--  http://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 162.0.215.52
# Connecting to pjreddie.com (pjreddie.com)|162.0.215.52|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://pjreddie.com/media/files/darknet53.conv.74 [following]
# --2024-04-11 03:08:42--  https://pjreddie.com/media/files/darknet53.conv.74
# Connecting to pjreddie.com (pjreddie.com)|162.0.215.52|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  48.4MB/s    in 3.4s
#
# 2024-04-11 03:09:31 (45.0 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !/content/darknet/darknet detector train /content/darknet/data/obj.data /content/darknet/data/yolov3_custom.cfg /content/darknet/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 3373, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = 133.095169, iou_loss = 0.000000, total_loss = 133.095169
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.410236), count: 4, class_loss = 647.893738, iou_loss = 2.546082, total_loss = 650.439819
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 2147.282227, iou_loss = 0.000000, total_loss = 2147.282227
#  total_bbox = 3377, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.358110), count: 2, class_loss = 133.054047, iou_loss = 0.902710, total_loss = 133.956757
# ...
